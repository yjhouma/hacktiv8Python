# %% [markdown]
# # Pandas
#
# Data 1: https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv
#
# Data 2: https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/property_data.csv
#
# Data 3: https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/opsd_germany_daily.csv

# %%
# Pandas
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv')

# %%
data.head(3)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# 0  1300.0000  1306.7233              H            L  0.640065   NaN
# 1  1300.0000  1293.2767              A            W  0.359935   NaN
# 2  1306.7233  1297.0712              H            W  0.631101   NaN
#
# [3 rows x 23 columns]

# %%
len(data)
# Out:
# 126314

# %%
data.shape
# Out:
# (126314, 23)

# %%
pd.set_option("display.max.columns", None)
pd.set_option("display.precision", 2)

# %%
data.tail(3)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 126311         101            1     CLE  Cavaliers   91  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers   97  1700.74  1692.09
# 126313         103            1     GSW   Warriors  105  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 126311      60.01    GSW   Warriors      104    1809.98    1813.63
# 126312      59.29    GSW   Warriors      105    1813.63    1822.29
# 126313      68.52    CLE  Cavaliers       97    1700.74    1692.09
#
#        game_location game_result  forecast notes
# 126311             A           L      0.23   NaN
# ...

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
data.describe()
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#            elo_i      elo_n  win_equiv    opp_pts  opp_elo_i  opp_elo_n  \
# count  126314.00  126314.00  126314.00  126314.00  126314.00  126314.00
# mean     1495.24    1495.24      41.71     102.73    1495.24    1495.24
# std       112.14     112.46      10.63      14.81     112.14     112.46
# ...

# %%
data["team_id"].value_counts()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# INJ      60
# PIT      60
# DTF      60
# TRH      60
# SDS      11
# Name: team_id, Length: 104, dtype: int64

# %%
data["fran_id"].value_counts()
# Out:
# Lakers          6024
# Celtics         5997
# Knicks          5769
# Warriors        5657
# Pistons         5650
# Sixers          5644
# Hawks           5572
# Kings           5475
# Wizards         4582
# Spurs           4309
# Bulls           4307
# Pacers          4227
# Thunder         4178
# Rockets         4154
# Nuggets         4120
# Nets            4106
# Suns            4080
# Bucks           4034
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Jazz            3555
# Mavericks       3013
# Heat            2371
# Pelicans        2254
# Magic           2207
# Timberwolves    2131
# Grizzlies       1657
# Raptors         1634
# Hornets          894
# Colonels         846
# Squires          799
# Spirits          777
# Stars            756
# Sounds           697
# Baltimore        467
# Floridians       440
# Condors          430
# Capitols         291
# Olympians        282
# Sails            274
# Stags            260
# Bombers          249
# ...

# %%
data.loc[data["fran_id"] == "Lakers", "team_id"].value_counts()
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
data.loc[data["team_id"] == "MNL", "date_game"].min()
# Out:
# '1/1/1949'

# %%
data.loc[data["team_id"] == "MNL", "date_game"].max()
# Out:
# '4/9/1959'

# %%
data.loc[data["team_id"] == "MNL", :]
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id   date_game  seasongame  \
# 1136        569  194811040BLB   NBA        1     1949   11/4/1948           1
# 1152        577  194811060WSC   NBA        1     1949   11/6/1948           2
# 1159        580  194811090BOS   NBA        1     1949   11/9/1948           3
# 1170        586  194811110NYK   NBA        1     1949  11/11/1948           4
# 1183        592  194811130PRO   NBA        1     1949  11/13/1948           5
# ...         ...           ...   ...      ...      ...         ...         ...
# 9701       4851  196003190LAL   NBA        0     1960   3/19/1960          80
# 9702       4852  196003200LAL   NBA        0     1960   3/20/1960          81
# 9709       4855  196003220STL   NBA        1     1960   3/22/1960          82
# 9711       4856  196003240LAL   NBA        0     1960   3/24/1960          83
# 9715       4858  196003260STL   NBA        1     1960   3/26/1960          84
#
# ...

# %%
data.loc[data["team_id"] == "LAL", "date_game"].min()
# Out:
# '1/1/1961'

# %%
data.loc[data["team_id"] == "LAL", "date_game"].max()
# Out:
# '6/9/2009'

# %%
# data.loc[data["team_id"] == "LAL", :]
data.loc[data["team_id"] == "LAL", "pts"].sum()
# Out:
# 549215

# %%
data["pts"]
# Out:
# 0          66
# 1          68
# 2          63
# 3          47
# 4          33
#          ...
# 126309     82
# 126310    104
# 126311     91
# 126312     97
# 126313    105
# Name: pts, Length: 126314, dtype: int64

# %% [markdown]
# ## Series

# %%
revenues = pd.Series([100,323,700])

# %%
revenues.values
# Out:
# array([100, 323, 700])

# %%
revenues
# Out:
# 0    100
# 1    323
# 2    700
# dtype: int64

# %%
city_revenues = pd.Series(
    [3000,5000,2100],
    index=["Amsterdam", "Toronto", "Tokyo"]
)

# %%
city_revenues
# Out:
# Amsterdam    3000
# Toronto      5000
# Tokyo        2100
# dtype: int64

# %%
city_employee_count = pd.Series(
    {
        "Amsterdam" : 5,
        "Tokyo": 9
    }
)

# %%
city_employee_count
# Out:
# Amsterdam    5
# Tokyo        9
# dtype: int64

# %%
city_employee_count.keys()
# Out:
# Index(['Amsterdam', 'Tokyo'], dtype='object')

# %%
"Tokyo" in city_employee_count
# Out:
# True

# %%
"Toronto" in city_employee_count.index
# Out:
# False

# %%
city_data = pd.DataFrame({
    "revenue": city_revenues,
    "employee_count": city_employee_count
})

# %%
city_data
# Out:
#            revenue  employee_count
# Amsterdam     3000             5.0
# Tokyo         2100             9.0
# Toronto       5000             NaN

# %%
city_data.index
# Out:
# Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object')

# %%
city_data.values
# Out:
# array([[3000.,    5.],
#        [2100.,    9.],
#        [5000.,   nan]])

# %%
city_data.axes[0]
# Out:
# Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object')

# %%
city_data.axes[1]
# Out:
# Index(['revenue', 'employee_count'], dtype='object')

# %%
city_data.columns
# Out:
# Index(['revenue', 'employee_count'], dtype='object')

# %%
"Tokyo" in city_data
# Out:
# False

# %%
"employee_count" in city_data
# Out:
# True

# %%
"Tokyo" in city_data.axes[0]
# Out:
# True

# %%
data
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=126314, step=1)

# %%
data.axes
# Out:
# [RangeIndex(start=0, stop=126314, step=1),
#  Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#         'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#         'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#         'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#        dtype='object')]

# %%
"points" in data.columns
# Out:
# False

# %%
"pts" in data.columns
# Out:
# True

# %% [markdown]
# ## Slicing

# %%
city_revenues
# Out:
# Amsterdam    3000
# Toronto      5000
# Tokyo        2100
# dtype: int64

# %%
city_revenues["Amsterdam"]
# Out:
# 3000

# %%
city_revenues[0:2]
# Out:
# Amsterdam    3000
# Toronto      5000
# dtype: int64

# %%
city_revenues["Amsterdam":"Toronto"]
# Out:
# Amsterdam    3000
# Toronto      5000
# dtype: int64

# %%
city_revenues[-1]
# Out:
# 2100

# %%
city_revenues[-1::-1]
# Out:
# Tokyo        2100
# Toronto      5000
# Amsterdam    3000
# dtype: int64

# %%
colors = pd.Series(
    ["red","purple", "blue", "green", "yellow"],
    index = [1,2,3,5,10]
)

# %%
colors
# Out:
# 1        red
# 2     purple
# 3       blue
# 5      green
# 10    yellow
# dtype: object

# %%
colors.loc[5]
# Out:
# 'green'

# %%
colors.iloc[4]
# Out:
# 'yellow'

# %%
colors.iloc[1:3]
# Out:
# 2    purple
# 3      blue
# dtype: object

# %%
colors.loc[3:10]
# Out:
# 3       blue
# 5      green
# 10    yellow
# dtype: object

# %%
colors.iloc[-1]
# Out:
# 'yellow'

# %%
# colors.loc[-1] # Hasilnya Error

# %%
data.loc[0,"game_id"]
# Out:
# '194611010TRH'

# %%
data.iloc[0,1]
# Out:
# '194611010TRH'

# %%
city_data
# Out:
#            revenue  employee_count
# Amsterdam     3000             5.0
# Tokyo         2100             9.0
# Toronto       5000             NaN

# %%
city_data["revenue"]
# Out:
# Amsterdam    3000
# Tokyo        2100
# Toronto      5000
# Name: revenue, dtype: int64

# %%
city_data.revenue
# Out:
# Amsterdam    3000
# Tokyo        2100
# Toronto      5000
# Name: revenue, dtype: int64

# %%
toys = pd.DataFrame(
    {
        "name": ["ball", "Rubik's cube"],
        "shape": ["sphere", "cube"]
    }
)

# %%
toys["shape"]
# Out:
# 0    sphere
# 1      cube
# Name: shape, dtype: object

# %%
toys.shape
# Out:
# (2, 2)

# %%
city_data.loc["Amsterdam"]
# Out:
# revenue           3000.0
# employee_count       5.0
# Name: Amsterdam, dtype: float64

# %%
city_data.iloc[1]
# Out:
# revenue           2100.0
# employee_count       9.0
# Name: Tokyo, dtype: float64

# %%
city_data.loc["Amsterdam", "revenue"]
# Out:
# 3000

# %%
data.iloc[-1]
# Out:
# gameorder               63157
# game_id          201506170CLE
# lg_id                     NBA
# _iscopy                     1
# year_id                  2015
# date_game           6/16/2015
# seasongame                103
# is_playoffs                 1
# team_id                   GSW
# fran_id              Warriors
# pts                       105
# elo_i                 1813.63
# elo_n                 1822.29
# win_equiv               68.52
# opp_id                    CLE
# opp_fran            Cavaliers
# opp_pts                    97
# opp_elo_i             1700.74
# opp_elo_n             1692.09
# game_location               A
# game_result                 W
# forecast                 0.52
# notes                     NaN
# Name: 126313, dtype: object

# %%
city_data.loc[["Amsterdam","Toronto"], ["revenue","employee_count"]]
# Out:
#            revenue  employee_count
# Amsterdam     3000             5.0
# Toronto       5000             NaN

# %% [markdown]
# ## Query Data Frame

# %%
data
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
current_decade = data[data["year_id"] > 2010]

# %%
current_decade
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113656      56829  201010260BOS   NBA        1     2011  10/26/2010
# 113657      56829  201010260BOS   NBA        0     2011  10/26/2010
# 113658      56830  201010260LAL   NBA        1     2011  10/26/2010
# 113659      56830  201010260LAL   NBA        0     2011  10/26/2010
# 113660      56831  201010260POR   NBA        1     2011  10/26/2010
# ...           ...           ...   ...      ...      ...         ...
# 126309      63155  201506110CLE   NBA        0     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015   6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015   6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 113656           1            0     MIA       Heat   80  1547.36  1543.16
# ...

# %%
current_decade.shape
# Out:
# (12658, 23)

# %%
notes_available = data[data['notes'].notnull()]

# %%
notes_available
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 930           466  194801300BLB   NBA        1     1948   1/30/1948
# 931           466  194801300BLB   NBA        0     1948   1/30/1948
# 1084          543  194803230CHS   NBA        1     1948   3/23/1948
# 1085          543  194803230CHS   NBA        0     1948   3/23/1948
# 1088          545  194803250CHS   NBA        1     1948   3/25/1948
# ...           ...           ...   ...      ...      ...         ...
# 122207      61104  201401160ATL   NBA        0     2014   1/16/2014
# 123916      61959  201411120MIN   NBA        1     2015  11/12/2014
# 123917      61959  201411120MIN   NBA        0     2015  11/12/2014
# 124862      62432  201501150MIL   NBA        0     2015   1/15/2015
# 124863      62432  201501150MIL   NBA        1     2015   1/15/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts    elo_i    elo_n  \
# ...

# %%
notes_available.shape
# Out:
# (5424, 23)

# %%
data[~data['notes'].isna()]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 930           466  194801300BLB   NBA        1     1948   1/30/1948
# 931           466  194801300BLB   NBA        0     1948   1/30/1948
# 1084          543  194803230CHS   NBA        1     1948   3/23/1948
# 1085          543  194803230CHS   NBA        0     1948   3/23/1948
# 1088          545  194803250CHS   NBA        1     1948   3/25/1948
# ...           ...           ...   ...      ...      ...         ...
# 122207      61104  201401160ATL   NBA        0     2014   1/16/2014
# 123916      61959  201411120MIN   NBA        1     2015  11/12/2014
# 123917      61959  201411120MIN   NBA        0     2015  11/12/2014
# 124862      62432  201501150MIL   NBA        0     2015   1/15/2015
# 124863      62432  201501150MIL   NBA        1     2015   1/15/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts    elo_i    elo_n  \
# ...

# %%
ers = data[data['fran_id'].str.endswith("ers")]

# %%
ers
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 7               4  194611020PRO   NBA        0     1947  11/2/1946
# 9               5  194611020STB   NBA        0     1947  11/2/1946
# 16              9  194611050DTF   NBA        1     1947  11/5/1946
# 20             11  194611070PRO   NBA        0     1947  11/7/1946
# 22             12  194611070STB   NBA        0     1947  11/7/1946
# ...           ...           ...   ...      ...      ...        ...
# 126304      63153  201506070GSW   NBA        1     2015   6/7/2015
# 126307      63154  201506090CLE   NBA        0     2015   6/9/2015
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts    elo_i    elo_n  \
# 7                1            0     PRO  Steamrollers   59  1300.00  1305.15
# ...

# %%
ers["fran_id"].nunique()
# Out:
# 9

# %%
ers['fran_id'].value_counts()
# Out:
# Lakers          6024
# Sixers          5644
# Pacers          4227
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Bombers          249
# Steamrollers     168
# Packers           72
# Name: fran_id, dtype: int64

# %%
data[
    (data["_iscopy"]==0) &
    (data["pts"] > 100) &
    (data["opp_pts"] > 100) &
    (data["team_id"] == "LAL")
]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 9744         4873  196010240LAL   NBA        0     1961  10/24/1960
# 9747         4874  196010250LAL   NBA        0     1961  10/25/1960
# 9778         4890  196011050LAL   NBA        0     1961   11/5/1960
# 9782         4892  196011060LAL   NBA        0     1961   11/6/1960
# 9786         4894  196011090LAL   NBA        0     1961   11/9/1960
# ...           ...           ...   ...      ...      ...         ...
# 125073      62537  201501290LAL   NBA        0     2015   1/29/2015
# 125301      62651  201502200LAL   NBA        0     2015   2/20/2015
# 125335      62668  201502220LAL   NBA        0     2015   2/22/2015
# 125450      62726  201503010LAL   NBA        0     2015    3/1/2015
# 126086      63044  201504120LAL   NBA        0     2015   4/12/2015
#
#         seasongame  is_playoffs team_id fran_id  pts    elo_i    elo_n  \
# 9744             3            0     LAL  Lakers  101  1450.41  1435.35
# ...

# %%
data[
    (data["_iscopy"]==0) &
    (data["team_id"].str.startswith("LA")) &
    (data["year_id"] == 1992) &
    (data["notes"].notna())
]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id date_game  seasongame  \
# 68901      34451  199205030LAC   NBA        0     1992  5/3/1992          86
# 68903      34452  199205030LAL   NBA        0     1992  5/3/1992          86
#
#        is_playoffs team_id   fran_id  pts    elo_i   elo_n  win_equiv opp_id  \
# 68901            1     LAC  Clippers  115  1546.90  1556.0      47.89    UTA
# 68903            1     LAL    Lakers   76  1489.65  1474.4      39.40    POR
#
#            opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# 68901          Jazz      107    1647.51    1638.41             H           W
# 68903  Trailblazers      102    1655.12    1670.37             H           L
#
#        forecast                                       notes
# 68901      0.50  at Anaheim, CA (Anaheim Convention Center)
# 68903      0.41                            at Las Vegas, NV

# %% [markdown]
# ## Grouping

# %%
city_revenues.sum()
# Out:
# 10100

# %%
city_revenues.max()
# Out:
# 5000

# %%
city_revenues.mean()
# Out:
# 3366.6666666666665

# %%
city_revenues.std()
# Out:
# 1484.362938547488

# %%
data[data['year_id'] > 2010].groupby(by="fran_id")["pts"].sum()
# Out:
# fran_id
# Bucks           38901
# Bulls           42723
# Cavaliers       40371
# Celtics         41512
# Clippers        44908
# Grizzlies       43130
# Hawks           43167
# Heat            47815
# Hornets         37081
# Jazz            38705
# Kings           39439
# Knicks          40847
# Lakers          42040
# Magic           38780
# Mavericks       43754
# Nets            40347
# Nuggets         43048
# Pacers          43155
# Pelicans        38677
# Pistons         38089
# Raptors         39971
# Rockets         44309
# Sixers          39183
# Spurs           48162
# Suns            39934
# Thunder         48093
# Timberwolves    39387
# Trailblazers    41633
# Warriors        44937
# Wizards         40140
# Name: pts, dtype: int64

# %%
data[
    (data["fran_id"] == "Celtics") &
    (data["year_id"] > 2010)
].groupby(by=["year_id", "team_id","game_result"])["game_id"].count()
# Out:
# year_id  team_id  game_result
# 2011     BOS      L              30
#                   W              61
# 2012     BOS      L              36
#                   W              50
# 2013     BOS      L              44
#                   W              43
# 2014     BOS      L              57
#                   W              25
# 2015     BOS      L              46
#                   W              40
# Name: game_id, dtype: int64

# %%
data[
    (data["fran_id"] == "Warriors") &
    (data["year_id"] == 2015)
].groupby(by=["year_id", "is_playoffs"])["pts"].mean()
# Out:
# year_id  is_playoffs
# 2015     0              109.95
#          1              103.29
# Name: pts, dtype: float64

# %%
nba = data.copy()

# %%
nba.shape
# Out:
# (126314, 23)

# %%
data.shape
# Out:
# (126314, 23)

# %%
nba["pts_diff"] = nba["pts"] - nba["opp_pts"]

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
nba.shape
# Out:
# (126314, 24)

# %%
nba["pts_diff"].max()
# Out:
# 68

# %%
nba["pts_diff"].min()
# Out:
# -68

# %%
nba["pts_diff_abs"] = np.abs(nba["pts_diff"])

# %%
nba[nba["pts_diff_abs"] == nba["pts_diff_abs"].min()]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 32             17  194611090STB   NBA        0     1947   11/9/1946
# 33             17  194611090STB   NBA        1     1947   11/9/1946
# 70             36  194611200DTF   NBA        1     1947  11/20/1946
# 71             36  194611200DTF   NBA        0     1947  11/20/1946
# 82             42  194611220TRH   NBA        1     1947  11/22/1946
# ...           ...           ...   ...      ...      ...         ...
# 126073      63037  201504110ORL   NBA        0     2015   4/11/2015
# 126270      63136  201505130ATL   NBA        0     2015   5/13/2015
# 126271      63136  201505130ATL   NBA        1     2015   5/13/2015
# 126288      63145  201505210GSW   NBA        0     2015   5/21/2015
# 126289      63145  201505210GSW   NBA        1     2015   5/21/2015
#
#         seasongame  is_playoffs team_id   fran_id  pts    elo_i    elo_n  \
# 32               4            0     STB   Bombers   70  1302.60  1305.73
# ...

# %%
nba.rename(
    columns={"game_result" : "result", "game_location":"location"}
    ,inplace=True
)

# %%
# nba_renamed
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 nba_renamed
#
# NameError: name 'nba_renamed' is not defined

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
elo_col = ["elo_i", "elo_n", "opp_elo_i", "opp_elo_n"]

# %%
nba.axes
# Out:
# [RangeIndex(start=0, stop=126314, step=1),
#  Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#         'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#         'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#         'opp_elo_n', 'location', 'result', 'forecast', 'notes', 'pts_diff',
#         'pts_diff_abs'],
#        dtype='object')]

# %%
nba.drop(elo_col, axis=1, inplace=True)

# %%
nba.shape
# Out:
# (126314, 21)

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 21 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   gameorder     126314 non-null  int64
#  1   game_id       126314 non-null  object
#  2   lg_id         126314 non-null  object
#  3   _iscopy       126314 non-null  int64
#  4   year_id       126314 non-null  int64
#  5   date_game     126314 non-null  object
#  6   seasongame    126314 non-null  int64
#  7   is_playoffs   126314 non-null  int64
#  8   team_id       126314 non-null  object
#  9   fran_id       126314 non-null  object
#  10  pts           126314 non-null  int64
#  11  win_equiv     126314 non-null  float64
#  12  opp_id        126314 non-null  object
#  13  opp_fran      126314 non-null  object
#  14  opp_pts       126314 non-null  int64
#  15  location      126314 non-null  object
#  16  result        126314 non-null  object
# ...

# %%
nba['location'].value_counts()
# Out:
# H    63138
# A    63138
# N       38
# Name: location, dtype: int64

# %%
nba['location']
# Out:
# 0         H
# 1         A
# 2         H
# 3         A
# 4         H
#          ..
# 126309    H
# 126310    H
# 126311    A
# 126312    H
# 126313    A
# Name: location, Length: 126314, dtype: object

# %%
nba['location'] = pd.Categorical(nba['location'])

# %%
nba['location'].dtype
# Out:
# CategoricalDtype(categories=['A', 'H', 'N'], ordered=False)

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 21 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   gameorder     126314 non-null  int64
#  1   game_id       126314 non-null  object
#  2   lg_id         126314 non-null  object
#  3   _iscopy       126314 non-null  int64
#  4   year_id       126314 non-null  int64
#  5   date_game     126314 non-null  object
#  6   seasongame    126314 non-null  int64
#  7   is_playoffs   126314 non-null  int64
#  8   team_id       126314 non-null  object
#  9   fran_id       126314 non-null  object
#  10  pts           126314 non-null  int64
#  11  win_equiv     126314 non-null  float64
#  12  opp_id        126314 non-null  object
#  13  opp_fran      126314 non-null  object
#  14  opp_pts       126314 non-null  int64
#  15  location      126314 non-null  category
#  16  result        126314 non-null  object
# ...

# %%
nba["pts_diff"] = nba["pts_diff"].astype(np.float64)

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 21 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   gameorder     126314 non-null  int64
#  1   game_id       126314 non-null  object
#  2   lg_id         126314 non-null  object
#  3   _iscopy       126314 non-null  int64
#  4   year_id       126314 non-null  int64
#  5   date_game     126314 non-null  object
#  6   seasongame    126314 non-null  int64
#  7   is_playoffs   126314 non-null  int64
#  8   team_id       126314 non-null  object
#  9   fran_id       126314 non-null  object
#  10  pts           126314 non-null  int64
#  11  win_equiv     126314 non-null  float64
#  12  opp_id        126314 non-null  object
#  13  opp_fran      126314 non-null  object
#  14  opp_pts       126314 non-null  int64
#  15  location      126314 non-null  category
#  16  result        126314 non-null  object
# ...

# %%
nba_no_miss_col = nba.dropna(axis=1)

# %%
nba_no_miss_col.shape
# Out:
# (126314, 20)

# %%
nba_no_miss_col.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 20 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   gameorder     126314 non-null  int64
#  1   game_id       126314 non-null  object
#  2   lg_id         126314 non-null  object
#  3   _iscopy       126314 non-null  int64
#  4   year_id       126314 non-null  int64
#  5   date_game     126314 non-null  object
#  6   seasongame    126314 non-null  int64
#  7   is_playoffs   126314 non-null  int64
#  8   team_id       126314 non-null  object
#  9   fran_id       126314 non-null  object
#  10  pts           126314 non-null  int64
#  11  win_equiv     126314 non-null  float64
#  12  opp_id        126314 non-null  object
#  13  opp_fran      126314 non-null  object
#  14  opp_pts       126314 non-null  int64
#  15  location      126314 non-null  category
#  16  result        126314 non-null  object
# ...

# %%
nba_copy = nba.copy()

# %%
nba_copy["notes"].fillna(
    value="No Note",
    inplace=True
)

# %%
nba_copy
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66      40.29    NYK
# ...

# %%
nba_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 21 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   gameorder     126314 non-null  int64
#  1   game_id       126314 non-null  object
#  2   lg_id         126314 non-null  object
#  3   _iscopy       126314 non-null  int64
#  4   year_id       126314 non-null  int64
#  5   date_game     126314 non-null  object
#  6   seasongame    126314 non-null  int64
#  7   is_playoffs   126314 non-null  int64
#  8   team_id       126314 non-null  object
#  9   fran_id       126314 non-null  object
#  10  pts           126314 non-null  int64
#  11  win_equiv     126314 non-null  float64
#  12  opp_id        126314 non-null  object
#  13  opp_fran      126314 non-null  object
#  14  opp_pts       126314 non-null  int64
#  15  location      126314 non-null  category
#  16  result        126314 non-null  object
# ...

# %%
nba_copy["notes"].describe()
# Out:
# count      126314
# unique        232
# top       No Note
# freq       120890
# Name: notes, dtype: object

# %%
nba[nba["pts"] == 0]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 26684      13343  197210260VIR   ABA        1     1973  10/26/1972
#
#        seasongame  is_playoffs team_id  fran_id  pts  win_equiv opp_id  \
# 26684           7            0     DNR  Nuggets    0      40.41    VIR
#
#       opp_fran  opp_pts location result  forecast  \
# 26684  Squires        2        A      L      0.33
#
#                                 notes  pts_diff  pts_diff_abs
# 26684  at Richmond VA; forfeit to VIR      -2.0             2

# %%
nba.drop(26684,axis=0)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66      40.29    NYK
# ...

# %%
nba[(nba["pts"] > nba["opp_pts"])]["result"].value_counts()
# Out:
# W    63157
# Name: result, dtype: int64

# %%
nba[(nba["pts"] < nba["opp_pts"]) & (nba['result'] == 'W')].empty
# Out:
# True

# %%
city_data
# Out:
#            revenue  employee_count
# Amsterdam     3000             5.0
# Tokyo         2100             9.0
# Toronto       5000             NaN

# %%
another_city_data = pd.DataFrame(
    {
    "revenue": [4500,8000],
    "employee_count": [2,2]
    }
    ,index=["New York", "Barcelona"]
    )

# %%
another_city_data
# Out:
#            revenue  employee_count
# New York      4500               2
# Barcelona     8000               2

# %%
all_city_data = pd.concat([city_data,another_city_data])

# %%
all_city_data
# Out:
#            revenue  employee_count
# Amsterdam     3000             5.0
# Tokyo         2100             9.0
# Toronto       5000             NaN
# New York      4500             2.0
# Barcelona     8000             2.0

# %%
city_countries = pd.DataFrame({
    "country": ["Holland", "Japan", "Holland", "Canada", "Spain"]
    ,"capital": [1,1,0,0,0]
}, index=["Amsterdam", "Tokyo","Rotterdam", "Toronto", "Barcelona"])

# %%
city_countries
# Out:
#            country  capital
# Amsterdam  Holland        1
# Tokyo        Japan        1
# Rotterdam  Holland        0
# Toronto     Canada        0
# Barcelona    Spain        0

# %%
cities = pd.concat([all_city_data, city_countries], axis=1)

# %%
all_city_data
# Out:
#            revenue  employee_count
# Amsterdam     3000             5.0
# Tokyo         2100             9.0
# Toronto       5000             NaN
# New York      4500             2.0
# Barcelona     8000             2.0

# %%
city_countries
# Out:
#            country  capital
# Amsterdam  Holland        1
# Tokyo        Japan        1
# Rotterdam  Holland        0
# Toronto     Canada        0
# Barcelona    Spain        0

# %%
all_city_data.merge(city_countries, left_index=True, right_index=True, how="left")
# Out:
#            revenue  employee_count  country  capital
# Amsterdam     3000             5.0  Holland      1.0
# Tokyo         2100             9.0    Japan      1.0
# Toronto       5000             NaN   Canada      0.0
# New York      4500             2.0      NaN      NaN
# Barcelona     8000             2.0    Spain      0.0

# %%
cities = pd.concat([all_city_data, city_countries], axis=1, join="inner")

# %%
cities
# Out:
#            revenue  employee_count  country  capital
# Amsterdam     3000             5.0  Holland        1
# Tokyo         2100             9.0    Japan        1
# Toronto       5000             NaN   Canada        0
# Barcelona     8000             2.0    Spain        0

# %%
countries = pd.DataFrame({
    "population": [17,127,37],
    "continent": ["Europe", "Asia", "North America"]
}, index=["Holland","Japan","Canada"])

# %%
countries
# Out:
#          population      continent
# Holland          17         Europe
# Japan           127           Asia
# Canada           37  North America

# %%
cities
# Out:
#            revenue  employee_count  country  capital
# Amsterdam     3000             5.0  Holland        1
# Tokyo         2100             9.0    Japan        1
# Toronto       5000             NaN   Canada        0
# Barcelona     8000             2.0    Spain        0

# %%
pd.merge(left=cities,right=countries, left_on="country", right_index=True, how="left")
# Out:
#            revenue  employee_count  country  capital  population  \
# Amsterdam     3000             5.0  Holland        1        17.0
# Tokyo         2100             9.0    Japan        1       127.0
# Toronto       5000             NaN   Canada        0        37.0
# Barcelona     8000             2.0    Spain        0         NaN
#
#                continent
# Amsterdam         Europe
# Tokyo               Asia
# Toronto    North America
# Barcelona            NaN

# %%
cities.merge(right=countries, left_on="country", right_index=True, how="left")
# Out:
#            revenue  employee_count  country  capital  population  \
# Amsterdam     3000             5.0  Holland        1        17.0
# Tokyo         2100             9.0    Japan        1       127.0
# Toronto       5000             NaN   Canada        0        37.0
# Barcelona     8000             2.0    Spain        0         NaN
#
#                continent
# Amsterdam         Europe
# Tokyo               Asia
# Toronto    North America
# Barcelona            NaN

# %%
# import matplotlib.pyplot as plt
# %matplotlib inline

# %%
nba[(nba["fran_id"] == "Warriors") & (nba['year_id'] >=2010)].groupby("year_id")["pts"].mean().plot()
# Out:
# <Axes: xlabel='year_id'>
